# %% [markdown]
# # Exercise
# - if
# - else
# - elif
# - nested

# %%
mylist=[1,2,3,5,6,7]
print(len(mylist))
# Out:
# 6

# %%
print(mylist[5])
# Out:
# 7

# %%
mylist1=["roshan","shubham","prashant","vikash","akash"]

# %%
print(mylist1[4])
# Out:
# akash

# %%
age=int(input('Enter your age'))
citizenship=input('Enter you country')

if age>=18:
    print('condition 1 is true')
    if citizenship=='india':
        print('condition 2 is true')
        print('eligible for vote')
    else:
        print('condition 1 is true but condition 2 is false')

        print(' not eligible for vote 1111')   
else:
    print(' not eligible for vote 222222')
# Out:
# condition 1 is true
# condition 2 is true
# eligible for vote
