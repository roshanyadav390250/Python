# %%
data = 'converts'

# %%
data[3:7]
# Out:
# 'vert'

# %%
lenth = len(data)

# %%
lenth
# Out:
# 8

# %%
dataa = 'roshanyadav'
print(dataa.capitalize())
# Out:
# Roshanyadav

# %%
name = 'roshan yadav kanaila atrauliya azamgarh'

# %%
print(name.find('yadav'))
# Out:
# 7

# %%
print(name.split())
# Out:
# ['roshan', 'yadav', 'kanaila', 'atrauliya', 'azamgarh']

# %%
print(name[2])
# Out:
# s

# %%
name[0:1]
# Out:
# 'r'

# %%
print(name.isalnum())
# Out:
# False

# %%
password = 'roshan  '

# %%
print(password.isalnum())
# Out:
# False

# %%
nikita = 'abs ent'

# %%
print(nikita.isspace())
# Out:
# False

# %%
ro = 'ra m'

# %%
print(ro.isspace())
# Out:
# False

# %%
name = '  '

# %%
print(name.isspace())
# Out:
# True

# %%
name=input('enter your number')
newname = int(name)
print(newname)
# Out:
# 34
