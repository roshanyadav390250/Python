# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import numpy as np

# %%
grid=np.array([
    [20,23,25,10],
    [45,65,85,95],
    [85,95,75,65],
    [45,95,35,85]
])

# %%
print('Row:',grid[2])
print(grid[0])
print('specific number:',grid[1,2])
print('column:',grid[:,0])
print(grid[0:2,0:2])
# Out:
# Row: [85 95 75 65]
# [20 23 25 10]
# specific number: 85
# column: [20 45 85 45]
# [[20 23]
#  [45 65]]

# %%
score = np.array([20,30,52,40,10,60,80])

# %%
print('15 above number:',score[score>=15])
# Out:
# 15 above number: [20 30 52 40 60 80]

# %%
print('less then 70:',score[score<=70])
# Out:
# less then 70: [20 30 52 40 10 60]
