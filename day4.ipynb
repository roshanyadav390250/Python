# %%
a=10
b=20
print(a+b)
print(b-a)
print(a*b)
print(b/a)
# Out:
# 30
# 10
# 200
# 2.0

# %%
print(a,b)
# Out:
# 10 20

# %%
a=10
b=20
c=30
d=40
e=50
print(a,b,c,d,e)
# Out:
# 10 20 30 40 50

# %%
a<=e
# Out:
# True

# %%
a==b or b > c or a==e
# Out:
# False

# %%
num1=(input('fist num'))
num2=input('second number')

num3=float(num1)
num4=float(num2)
print(num3+num4)
# Out:
# 66.0
