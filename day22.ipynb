# %%
arr=[20,30,40,50]
for i,val in enumerate(arr):
    if val==40:
        print("found")
# Out:
# found

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## static vs dynamic

# %% [markdown]
# #### static

# %%
l2=[20,30,40,50]

# %%
print(l2)
# Out:
# [20, 30, 40, 50]

# %% [markdown]
# #### dynamic

# %%
l3=[]

# %%
l3.append(10)

# %%
print(l3)
# Out:
# [10]

# %%
x=5
y=3
if x>4 and y<5:
    print(x+y)
else:
    print(x)
# Out:
# 8

# %%
x=7 
if x%2==0:
    print("even")
elif x>5:
    print("greater than 5")
else:
    print("odd")
# Out:
# greater than 5

# %%
x = 4
x = 6
print(x)
# Out:
# 6

# %%
name = "python"
if name == "java" or "c":
    print("valid")
else:
    print("invalid")
# Out:
# valid
