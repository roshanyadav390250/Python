# %%
print('hello')
# Out:
# hello

# %%
print('helloharendra')
# Out:
# helloharendra

# %%
print('Naya Prayog academy, Atrauliya azamgarh up 223223')
# Out:
# Naya Prayog academy, Atrauliya azamgarh up 223223

# %%
address='Naya Prayog academy, Atrauliya azamgarh up 223223'

# %%
print(address)
# Out:
# Naya Prayog academy, Atrauliya azamgarh up 223223

# %%
print(address*10)
# Out:
# Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223Naya Prayog academy, Atrauliya azamgarh up 223223

# %%
print(2+8)
# Out:
# 10

# %%
print(2*8)
# Out:
# 16

# %%
a=10
b=5
c=a+b

# %%
print(c)
# Out:
# 15

# %%
c=(a-b)

# %%
print(c)
# Out:
# 5

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
type(a)
# Out:
# int

# %%
type(address)
# Out:
# str

# %%
d=1.50

# %%
type(d)
# Out:
# float

# %%
e=54564566565665.01

# %%
type(e)
# Out:
# float

# %%
male=True

# %%
type(male)
# Out:
# bool

# %%
#input and output --> Single line comment

# %%
''' this is multi line comment '''
# Out:
# ' this is multi line comment '
